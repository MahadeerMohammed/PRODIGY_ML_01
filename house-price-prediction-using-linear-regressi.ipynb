# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
for dirname, _, filenames in os.walk("E:\Prodigy_tasks\property.csv"):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv("E:\Prodigy_tasks\property.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  sqft_above  sqft_basement  yr_built  \
# 0             1180      5650        1180              0      1955
# ...

# %%
df.shape
# Out:
# (21613, 16)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  2.161300e+04  21613.000000   21613.000000  21613.000000  21613.000000
# mean   1.510697e+04   1788.390691     291.509045   1971.005136     84.402258
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# dtype: object

# %%
plt.figure(figsize=(20,6))
df['yr_built'].value_counts().plot(kind='bar')
plt.title('Built and House frequency')
plt.xlabel('Built')
plt.ylabel('Value Count')
# Out:
# Text(0, 0.5, 'Value Count')

# %%
df['bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['bathrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bathrooms')
plt.xlabel('Bathrooms')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['floors'].value_counts().plot(kind='bar')
plt.title('Number of floors')
plt.xlabel('floors')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['waterfront'].value_counts().plot(kind='bar')
plt.title('Number of waterfront')
plt.xlabel('waterfront')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['condition'].value_counts().plot(kind='bar')
plt.title('Number of condition')
plt.xlabel('condition')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['grade'].value_counts().plot(kind='bar')
plt.title('Number of grade')
plt.xlabel('grade')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.scatter(df.bedrooms,df.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df.bathrooms,df.price)
plt.title("Bathrooms and Price ")
plt.xlabel("Bathrooms")
plt.ylabel("Price")
plt.show()

# %%
Total_Area=df.sqft_living+df.sqft_lot+df.sqft_above+df.sqft_basement
df["Total_Area"] = Total_Area

df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  sqft_above  sqft_basement  yr_built  \
# 0             1180      5650        1180              0      1955
# ...

# %%
df.plot.scatter('price','Total_Area')
# Out:
# <Axes: xlabel='price', ylabel='Total_Area'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'Total_Area'],
#       dtype='object')

# %%
ax = plt.figure(figsize=(6,6)).add_subplot(111)
ax.set_title('Price for Houses')

bp = ax.boxplot([df['bedrooms'], df['bathrooms']])

# %%
del df['date']
df
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  floors  waterfront  \
# ...

# %%
X = df[[ 'bedrooms','bathrooms','sqft_living','sqft_lot','sqft_above','sqft_basement','yr_built','yr_renovated','floors','waterfront','view','condition','grade']]

y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 6144567.26375449

# %%
coeff_df = pd.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# bedrooms       -37793.045606
# bathrooms       41402.579457
# sqft_living       113.644686
# sqft_lot           -0.236423
# sqft_above         53.428462
# sqft_basement      60.216223
# yr_built        -3549.560281
# yr_renovated       11.436853
# floors          28501.841940
# waterfront     547524.316814
# view            43561.239924
# condition       20599.817641
# grade          125001.342739

# %%
predictions = lr.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.distplot((y_test-predictions),bins=50);

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 137795.7231554267
# MSE: 53813665566.28984
# RMSE: 231977.72644435035

# %%
lr.score(X,y)
# Out:
# 0.6521467271447887

# %%
X.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'floors', 'waterfront',
#        'view', 'condition', 'grade'],
#       dtype='object')

# %%
print("House price is:",lr.predict([[4,4,2900,1500,1000,1500,1990,1990,4,1,1,4,9]]))
# Out:
# House price is: [1503611.81014139]
